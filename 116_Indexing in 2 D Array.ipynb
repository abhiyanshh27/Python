# %%
# Creating 2 D Array

# %%
import numpy as np

# %%
myarr = np.array([[5,10,15],[20,25,30],[35,40,45]])

# %%
myarr
# Out:
# array([[ 5, 10, 15],
#        [20, 25, 30],
#        [35, 40, 45]])

# %%
# Indexing using double bracket notation

# %%
myarr[0][1]
# Out:
# 10

# %%
# Indexing using single bracket notation

# %%
myarr[0,1]
# Out:
# 10
