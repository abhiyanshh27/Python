# %%
import numpy as np

# %%
myarr = np.diag([1,5,3,7])

# %%
myarr
# Out:
# array([[1, 0, 0, 0],
#        [0, 5, 0, 0],
#        [0, 0, 3, 0],
#        [0, 0, 0, 7]])

# %%
import numpy as np

# %%
list = [[1,4,7],[2,5,8],[3,6,9]]

# %%
myarr2 = np.array(list)

# %%
myarr2
# Out:
# array([[1, 4, 7],
#        [2, 5, 8],
#        [3, 6, 9]])

# %%
# To get the diagonal elements in a two dimesional array we use diag as a function.

# %%
np.diag(myarr2)
# Out:
# array([1, 5, 9])
