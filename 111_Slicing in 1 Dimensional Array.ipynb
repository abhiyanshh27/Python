# %%
import numpy as np

# %%
list = [5,10,15,20,25]

# %%
list = np.array(list)

# %%
list
# Out:
# array([ 5, 10, 15, 20, 25])

# %%
# Slicing with positive number-[:]>[Start : End : Step]

# %%
list[0:]
# Out:
# array([ 5, 10, 15, 20, 25])

# %%
list[1:]
# Out:
# array([10, 15, 20, 25])

# %%
list[1:3]
# Out:
# array([10, 15])

# %%
list[:2]
# Out:
# array([ 5, 10])

# %%
# Slicing with negative number

# %%
list[:]
# Out:
# array([ 5, 10, 15, 20, 25])

# %%
list[-2]
# Out:
# 20

# %%
list[:-4]
# Out:
# array([5])

# %%
list[:-1]
# Out:
# array([ 5, 10, 15, 20])

# %%
# [start : end : steps]

# %%
list[:]
# Out:
# array([ 5, 10, 15, 20, 25])

# %%
list[1:4:1]
# Out:
# array([10, 15, 20])

# %%
list[1:2:3]
# Out:
# array([10])

# %%
# Reverse array by

# %%
list[:]
# Out:
# array([ 5, 10, 15, 20, 25])

# %%
list[::-1]
# Out:
# array([25, 20, 15, 10,  5])
