# %%
# one d

# %%
import numpy as npa

# %%
myarr = npa.zeros(5)

# %%
myarr
# Out:
# array([0., 0., 0., 0., 0.])

# %%
# Multi D

# %%
myarr2 = npa.zeros((2,3))

# %%
myarr2
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])
