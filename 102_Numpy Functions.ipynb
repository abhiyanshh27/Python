# %%
# One D

# %%
import numpy as np

# %%
myarr = np.ones(5)

# %%
myarr
# Out:
# array([1., 1., 1., 1., 1.])

# %%
# Multi D

# %%
myarr2 = np.ones((2,3))

# %%
myarr2
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])
