# %%
# Use of shape and dtype

# %%
import numpy as np

# %%
nums = [[[1,2,3],[4,5,6]],[[1,2,3],[7,8,9]]]

# %%
nums = np.array(nums)

# %%
nums
# Out:
# array([[[1, 2, 3],
#         [4, 5, 6]],
#
#        [[1, 2, 3],
#         [7, 8, 9]]])

# %%
nums.ndim
# Out:
# 3

# %%
nums.shape
# Out:
# (2, 2, 3)

# %%
nums.dtype
# Out:
# dtype('int32')
