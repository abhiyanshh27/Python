# %%
import numpy as np

# %%
myarr=np.random.randint(1,100,10)

# %%
myarr
# Out:
# array([81, 13, 14, 89, 61, 30, 48,  6, 41, 16])

# %%
# RUN 2nd Time

# %%
import numpy as np

# %%
myarr=np.random.randint(1,100,10)
myarr
# Out:
# array([30,  3, 69, 64, 26, 59, 57, 28, 50, 27])

# %%
# After using Seed Function

# %%
import numpy as np

# %%
np.random.seed(1)
myarr=np.random.randint(1,100,10)
myarr
# Out:
# array([38, 13, 73, 10, 76,  6, 80, 65, 17,  2])

# %%
# RUN 2nd Time

# %%
import numpy as np

# %%
np.random.seed(9)
myarr=np.random.randint(1,100,10)

# %%
myarr
# Out:
# array([93, 55, 57, 23, 66, 23, 53, 60, 41, 92])

# %%
myarr.size
# Out:
# 10
