# %%
# 1st Method

# %%
import numpy as np

# %%
list = [1,2,3,4,5]

# %%
myarr = np.array(list)

# %%
myarr
# Out:
# array([1, 2, 3, 4, 5])

# %%
# 2nd Method

# %%
myarr2 = np.array([1,2,3,4,5])

# %%
myarr
# Out:
# array([1, 2, 3, 4, 5])
