# %%
import numpy as np

# %%
myarr = np.random.randint(1,100,20)

# %%
myarr
# Out:
# array([69,  7, 92, 18, 38, 74, 86, 92, 57,  2, 71, 55, 59, 96, 23, 32, 59,
#        46, 88, 24])

# %%
myarr.ndim
# Out:
# 1

# %%
myarr.shape
# Out:
# (20,)

# %%
# Reshape : convert one D to mulit D or multi D to one D

# %%
myarr = np.random.randint(1,100,20)
myarr = myarr.reshape(2,10)

# %%
myarr
# Out:
# array([[53, 42, 88,  3, 84, 87, 14, 87, 60, 49],
#        [41, 17, 31, 27, 30, 86, 47, 32, 30, 38]])

# %%
myarr.ndim
# Out:
# 2

# %%
myarr.shape
# Out:
# (2, 10)
