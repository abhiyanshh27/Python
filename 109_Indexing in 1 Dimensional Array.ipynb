# %%
import numpy as np

# %%
list = [5,10,15,20,25]

# %%
list = np.array(list)

# %%
list
# Out:
# array([ 5, 10, 15, 20, 25])

# %%
list[0]
# Out:
# 5

# %%
list[4]
# Out:
# 25

# %%
list[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13848/2754255825.py in <module>
# ----> 1 list[9]
#
# IndexError: index 9 is out of bounds for axis 0 with size 5

# %%
list[2]
# Out:
# 15

# %%
list[-3]
# Out:
# 15

# %%
list[-4]
# Out:
# 10
