# %%
# Creating 2D Array

# %%
import numpy as np

# %%
myarr = np.array([[5,0,5],[20,25,30],[35,40,45]])

# %%
myarr
# Out:
# array([[ 5,  0,  5],
#        [20, 25, 30],
#        [35, 40, 45]])

# %%
# array_nampe[start:end:step,start:end:step]

# %%
myarr[0:,0:]
# Out:
# array([[ 5,  0,  5],
#        [20, 25, 30],
#        [35, 40, 45]])

# %%
myarr[:2,:2]
# Out:
# array([[ 5,  0],
#        [20, 25]])

# %%
myarr[1:,1:]
# Out:
# array([[25, 30],
#        [40, 45]])
